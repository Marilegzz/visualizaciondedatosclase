# %% [markdown]
# # Welcome to an example Binder

# %% [markdown]
# We need `seaborn`, which shall be included it in `requirements.txt` file

# %%
import pandas as pd
import numpy as np
from scipy import stats
from pylab import *

stats.norm.rvs(size=10)
# Out:
# array([ 1.42297148,  3.10251291, -1.02550645, -0.81803149, -0.12643791,
#         0.59204644,  1.41509044,  1.2373083 ,  1.32121449,  0.05481963])

# %%
dx=0.01
x= np.arange(-2,2,dx)
y=exp(-x**2)

plot(x,y)

# %%
import matplotlib.pyplot as plt
ax=plt.plot(2,3,'x')
plt.title('A title')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
data={
    'Name':['Jim', 'Dwight', 'Juan', 'Ana'],
    'Age':[30, 32, 40, 20],
    'Weight':[47,68,87,40]
}

df=pd.DataFrame(data)
df
# Out:
#      Name  Age  Weight
# 0     Jim   30      47
# 1  Dwight   32      68
# 2    Juan   40      87
# 3     Ana   20      40

# %%
una_variable=df.plot()

# %%
df.plot()

# %%
df['Age'].plot(kind='hist')

# %%
df['Weight'].plot(kind='hist')

# %%
df=pd.read_csv('datasets/Cartwheeldata.csv')
df.head(2)
# Out:
#    ID  Age Gender  GenderGroup Glasses  GlassesGroup  Height  Wingspan  \
# 0   1   56      F            1       Y             1    62.0      61.0
# 1   2   26      F            1       Y             1    62.0      60.0
#
#    CWDistance Complete  CompleteGroup  Score
# 0          79        Y              1      7
# 1          70        Y              1      8

# %%
import seaborn as sns

sns.lmplot(
    x='Wingspan',
    y='CWDistance',
    data= df,
    fit_reg= False,
    hue='Gender'
)
plt.show()
